# %% [markdown]
# # ETL COM PANDAS E SELENIUM
# <br>

# %% [markdown]
# <p><big>ETL é o processo de importação, tratamento e exportação de uma base de dados afim de localizar e filtrar as informações mais relevantes para um determinado negócio.</big></p>
#
# <p><big>O pandas é uma biblioteca de software criada para a linguagem Python para manipulação e análise de grandes volumes de dados, sendo utilizada no presente notebook para realizar o processo de ETL.</big></p>
#
# <p><big>E Selenium é um conjunto de ferramentas de código aberto multiplataforma, usado para testar aplicações web pelo browser de forma automatizada, que também será utilizado para auxiliar o tratamento de dados, extraindo informações atualizadas da web.</big></p>
#
# <p><big>A base de dados escolhida para este projeto contempla produtos importados pelo Brasil de países extrangeiros. O objetivo do projeto é aliar os conhecimentos em engenharia de dados com Python e automação web com Selenium para definir qual seria o preço atualizado que o Brasil pagaria hoje pela importação dos respectivos produtos.</big></p>

# %% [markdown]
# ---
#
# ## PREPARAÇÃO DO AMBIENTE:
#
# <br>

# %%
# INSTALANDO O SELENIUM

# !pip install selenium

# %%
# IMPORTANDO BIBLIOTECAS

import pandas as pd # Biblioteca pandas, usada para analise de dados.
import numpy as np # Biblioteca numpy, usada para realizar operacoes em arranjos complexos
import time # Biblioteca time, usada para criar intervalos de tempo, etc.
from selenium import webdriver # Modulo webdriver, usado para que o Selenium se comunique com o navegador.
from selenium.webdriver.common.keys import Keys # Modulo Keys, usado para que o navegador acesse o teclado.
from selenium.webdriver.common.by import By # Modulo By, usado para localizar elementos na pagina web.

# %% [markdown]
# ---
#
# ## AUTOMAÇÃO DE BUSCAS ONLINE:
#
# <br>

# %% [markdown]
# <p><big>Para utilizar o Selenium, é necessário que o webdriver do navegador em uso esteja na mesma pasta que está o executável do python ou na mesma pasta que esta o notebook. Pois o Selenium usa o próprio webdriver do navegador para manupulá-lo.</big></p>
#
# <br>
#
#  * NAVEGADOR/BROWSER

# %%
# INSTANCIANDO UM NAVEGADOR/BROWSER

browser = webdriver.Chrome() #Por meio do browser, o Selenium se comunicara com o navegador

# %% [markdown]
# <br>
#
# * COTAÇÃO DO DOLAR

# %%
# ABRINDO UMA PAGINA NA WEB (GOOGLE)

link = 'https://www.google.com/'
browser.get(link)
time.sleep(5)


# SELECIONANDO UM ELEMENTO DA PÁGINA (CAIXA DE PESQUISA) E INSERINDO TEXTO (COTAÇÃO DOLAR)

caminho = '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input'
(browser.find_element(By.XPATH, caminho )
        .send_keys('cotação dolar'))


# SELECIONANDO UM ELEMENTO DA PÁGINA (CAIXA DE PESQUISA) E ENVIANDO "ENTER" DO TECLADO

(browser.find_element(By.XPATH, caminho)
        .send_keys(Keys.ENTER))


# SELECIONANDO UM ELEMENTO DA PÁGINA (VALOR DA COTAÇÃO DO DOLAR) E O GUARDANDO EM UMA VARIÁVEL

caminho = '//*[@id="knowledge-currency__updatable-data-column"]/div[1]/div[2]/span[1]'
cot_dolar = (browser.find_element(By.XPATH, caminho)
                    .get_attribute('data-value'))

print(cot_dolar)
# Out:
# 5.420599999999999

# %% [markdown]
# <br>
#
# * COTAÇÃO DO EURO

# %%
# LIMPANDO A CAIXA DE PESQUISA

caminho = '//*[@id="tsf"]/div[1]/div[1]/div[2]/div[1]/div/div[3]/div[1]'
browser.find_element(By.XPATH, caminho).click()


# SELECIONANDO UM ELEMENTO DA PÁGINA (CAIXA DE PESQUISA) E INSERINDO TEXTO (COTAÇÃO EURO)

caminho = '//*[@id="tsf"]/div[1]/div[1]/div[2]/div[1]/div/div[2]/input'
(browser.find_element(By.XPATH, caminho)
        .send_keys('cotação euro'))


# SELECIONANDO UM ELEMENTO DA PÁGINA (CAIXA DE PESQUISA) E ENVIANDO "ENTER" DO TECLADO

(browser.find_element(By.XPATH, caminho)
        .send_keys(Keys.ENTER))


# SELECIONANDO UM ELEMENTO DA PÁGINA (VALOR DA COTAÇÃO DO EURO) E O GUARDANDO EM UMA VARIÁVEL

caminho = '//*[@id="knowledge-currency__updatable-data-column"]/div[1]/div[2]/span[1]'
cot_euro = (browser.find_element(By.XPATH, caminho)
                    .get_attribute('data-value'))

print(cot_euro)
# Out:
# 6.039207475

# %% [markdown]
# <br>
#
# * COTAÇÃO DA LIBRA

# %%
# LIMPANDO A CAIXA DE PESQUISA

caminho = '//*[@id="tsf"]/div[1]/div[1]/div[2]/div[1]/div/div[3]/div[1]'
browser.find_element(By.XPATH, caminho).click()


# SELECIONANDO UM ELEMENTO DA PÁGINA (CAIXA DE PESQUISA) E INSERINDO TEXTO (COTAÇÃO LIBRA)

caminho = '//*[@id="tsf"]/div[1]/div[1]/div[2]/div[1]/div/div[2]/input'
(browser.find_element(By.XPATH, caminho)
        .send_keys('cotação libra'))


# SELECIONANDO UM ELEMENTO DA PÁGINA (CAIXA DE PESQUISA) E ENVIANDO "ENTER" DO TECLADO

(browser.find_element(By.XPATH, caminho)
        .send_keys(Keys.ENTER))


# SELECIONANDO UM ELEMENTO DA PÁGINA (VALOR DA COTAÇÃO DA LIBRA) E O GUARDANDO EM UMA VARIÁVEL

caminho = '//*[@id="knowledge-currency__updatable-data-column"]/div[1]/div[2]/span[1]'
cot_libra = (browser.find_element(By.XPATH, caminho)
                    .get_attribute('data-value'))


# FECHANDO A PÁGINA

browser.quit()
print(cot_libra)
# Out:
# 7.2491200970000005

# %% [markdown]
# ---
#
# ## ETL - EXTRAÇÃO, TRATAMENTO E CARREGAMENTO:
#
# <br>

# %% [markdown]
# * EXTRAÇÃO: DOWNLOAD E IMPORTAÇÃO DA BASE DE DADOS

# %%
# ABRINDO A PAGINA ONDE SE ECNONTRA A BASE DE DADOS

link = 'https://dados.ufabc.edu.br/bases-dados/9-bd-proad02'
browser = webdriver.Chrome()
browser.get(link)
time.sleep(3)


# FAZENDO DOWNLOAD DA BASE DE DADOS

caminho = '//*[@id="main"]/article/p[19]/a'
browser.find_element(By.XPATH, caminho).click()


# ESPERANDO TEMPO DO DOWNLOAD

time.sleep(5)


# FECHANDO A PÁGINA

browser.quit()

# IMPORTANDO A BASE DE DADOS PARA O NOTEBOOK (RENOMEANDO COLUNAS PARA FACILITAR A MANIPULACAO DO DF)

caminho = r'C:\Users\Fenrir\Downloads\bd_proad02_jan2022.csv'
novo_cabecalho = ['NUM_PROCESSO', 'PRODUTO_OU_SERVICO', 'EXPORTADOR', 'NUM_DISPENSA', 'LICENCA_IMPORTACAO', 'PAIS_EMBARQUE', 'MOEDA', 'VALOR_MOEDA_EXTERIOR', 'INCOTERM', 'CONDICAO_PAGAMENTO', 'NOTA_EMPENHO', 'DECLARACAO_IMPORTACAO', 'DESP_CAMBIO_BANCO', 'DESP_FORNECEDOR', 'DESP_ORGAO_ANUENTE']

df = (pd.read_csv(caminho, sep=';', 
                  encoding='ISO-8859-1',
                  header=0,
                  names=novo_cabecalho)
     )
display(df)
# Out:
#             NUM_PROCESSO                                 PRODUTO_OU_SERVICO  \
# 0   23006.002364/2018-15  Microscópio Eletrônico de Transmissão de Alta ...
# 1   23006.000168/2019-89              29 Criotubos contendo Células Humanas
# 2   23006.000197/2019-41  Sistema medidor de óxido nítrico, nitrito e ni...
# 3   23006.000601/2019-86                         Barras de Liga de Magnésio
# 4   23006.000603/2019-75       Consumíveis para pesquisa com a técnica NIRS
# 5   23006.000613/2019-19        Peça para Sistema de Neuronavegação Patriot
# 6   23006.000748/2019-76  Capilares para Medidas de Difração de Raios X ...
# 7   23006.000847/2019-58                                    Células Bovinas
# 8   23006.000771/2019-61  Peças de Reposição (placas GE e sonda hall) pa...
# 9   23006.000964/2019-11  Contratação de serviço de acesso online ao Sis...
# 10  23006.000944/2019-41  Analisador de Redes Vetorial (1u); Impressora ...
# 11  23006.001020/2019-61                          Tubos Espectrais e Fontes
# 12  23006.001435/2019-35                                 Fontes Radioativas
# 13  23006.001602/2019-48  Reagentes e Amostras Inclusas em Parafina e Stubs
# 14  23006.001788/2019-35  Componentes e acessórios para o Microscópio El...
# 15  23006.001382/2020-96  Componentes eletrônicos para desenvolvimento d...
# 16  23006.001649/2020-45                                          Reagentes
# 17  23006.001729/2020-09                            Micromedidores de Vazão
# 18  23006.002838/2020-35  Sistema de Mediação de Propriedades Física da ...
# 19  23006.002840/2020-12  Equipamento de Medição de Momentos Magnéticos ...
# 20  23006.002177/2020-48  Sensor de Pressão para o Espectrômetro de foto...
# 21  23006.001866/2020-35                     Tubo de Molibdênio para Raio-X
# 22  23006.002293/2020-67                  Reagentes para Estudo do COVID-19
# 23  23006.002281/2020-32  Insumos para utilização e aplicação da técnica...
# 24  23006.003663/2020-83  Contratação de serviço de assinatura online à ...
# 25  23006.003497/2020-15  Licenciamento Temporário por 5 anos da ferrame...
# 26  23006.002325/2020-24                         Sistema de rastreio ocular
# 27  23006.001256/2020-31  Acesso à base de dados da Classificação Decima...
# 28  23006.002386/2020-91                                          Reagentes
# 29  23006.002378/2020-45         Microscópio Biológico Invertido Trinocular
# 46                            Inexigibilidade 51/2020
# 47                                   Dispensa 30/2021
# 48                                   Dispensa 23/2021
# 49                                   Dispensa 31/2021
# 50                            Inexigibilidade 54/2021
# 51                            Inexigibilidade 37/2021
# 52                              Ainda não formalizado
# 53                              Ainda não formalizado
# 54                              Ainda não formalizado
# 55                                   Dispensa 34/2021
# 56                            Inexigibilidade 56/2021
# 57                            Inexigibilidade 43/2021
# 58                              Ainda não formalizado
# 59                            Inexigibilidade 52/2021
#
#                                    LICENCA_IMPORTACAO  \
# 0                                        20/0816417-0
# 1                                        19/0530257-0
# 2                                        19/1273133-3
# 3                                        19/1609331-5
# 4                          19/1874413-5\n19/1874446-1
# 5                                        19/2109818-4
# 6                          19/2200479-5\n19/2200614-3
# 7                                        19/2132380-3
# 8          Não sujeita a Licenciamento Não-Automático
# 9                                       Não se aplica
# 10           19/2934303-0\n19/2934751-5\n19/2934860-0
# 11         Não sujeita a Licenciamento Não-Automático
# 12                                       20/2200143-7
# 13  19/4016057-4\n19/4016106-6\n19/4016132-5\n19/4...
# 14           19/4123731-7\n19/4123775-9\n19/4123831-3
# 15                         20/1633940-5\n20/1634349-6
# 16                                       20/1687205-7
# 17           20/3137341-4\n20/3137365-1\n20/3137746-0
# 18                                       20/3294513-6
# 19                                       20/2641314-4
# 20                                      20/1900784-5
# 21                                       20/1998713-0
# 22                                       20/1772533-3
# 23                         20/2073398 8\n20/2085260 0
# 24                                      Não se aplica
# 25                                      Não se aplica
# 26                                       20/2534073-9
# 27                                      Não se aplica
# 28  20/3362765-0\n20/3362620-4\n20/3362663-8\n20/3...
# 29                                                NaN
# 30                                                NaN
# 31                                       21/0172986-7
# 32                                      Não se aplica
# 33                                       21/3042828-4
# 34                                       21/2599170-7
# 35                                       21/1145173-0
# 36                         21/2598941-9\n21/2598975-3
# 37                                       21/2632471-2
# 38  21/1740870-4\n21/1741265-5\n21/1744172-8\n21/1...
# 39                                       21/1747844-3
# 40   21/1737902-0\n21/1737930-5\n21/1737697-7\n21/...
# 41                                       21/3216437-3
# 42                                       21/3414987-8
# 43                         21/3362282-0\n21/3357019-7
# 44                                                NaN
# 45                                       21/3226562-5
# 46                                      Não se aplica
# 47                         21/3488060-2\n21/3488224-9
# 48                                       21/3548175-2
# 49                                       21/3550065-0
# 50                                      Não se aplica
# 51                                      Não se aplica
# 52                                  Ainda não emitida
# 53                                  Ainda não emitida
# 54                                      Não se aplica
# 55                                       21/3551353-0
# 56                                      Não se aplica
# 57                                      Não se aplica
# 58                                      Não se aplica
# 59                                      Não se aplica
#
#                                         PAIS_EMBARQUE MOEDA  \
# 0                                    República Tcheca   USD
# 1                                      Estados Unidos   USD
# 2                                      Estados Unidos   USD
# 3                                               China   USD
# 4                                            Alemanha   USD
# 5                                      Estados Unidos   USD
# 6                                            Alemanha   EUR
# 7                                              Itália   USD
# 8                                            Alemanha   EUR
# 9   Não envolve embarque, mas o prestador de servi...   USD
# 25            56.232,16                     Não se aplica (serviço)
# 26             3.075,00                       FCA Vancouver Airport
# 27               787,50                     Não se aplica (serviço)
# 28                10,00                  CPT Aeroporto de Guarulhos
# 29                  NaN                                         NaN
# 30                  NaN                                         NaN
# 31            65.672,80                      FCA Montevideo Airport
# 32               800,00                     Não se aplica (serviço)
# 33             2.455,00                           FCA Miami Airport
# 34               698,86                FCA cidade de Best (Holanda)
# 35                 0,70                                         EXW
# 36             9.732,00                           FCA Miami Airport
# 37             5.370,00                       FCA Frankfurt Airport
# 38                10,00                  CPT Aeroporto de Guarulhos
# 39                 5,00                                         EXW
# 40             4.100,00                                         EXW
# 41             1.203,16                      FCA Copenhagen Airport
# 42            71.000,00                           FCA Miami Airport
# 43           108.775,68                           FCA Miami Airport
# 44                  NaN                                         NaN
# 45            61.066,06               FCA London Airport (Heathrow)
# 46            91.174,25                     Não se aplica (serviço)
# 47            16.909,50                           FCA Miami Airport
# 48               664,13  FCA cidade de Peabody, MA (Estados Unidos)
# 49             5.109,00       FCA cidade de Brno (República Tcheca)
# 50             8.540,00                         FCA Toronto Airport
# 51             8.500,00                     Não se aplica (serviço)
# 52            26.604,00                           FCA Miami Airport
# 53            30.644,16                           FCA Miami Airport
# 54             7.087,00                     Não se aplica (serviço)
# 55             1.716,35                           FCA Miami Airport
# 56               826,88                     Não se aplica (serviço)
# 57               215,00                     Não se aplica (serviço)
# 58            55.838,00                     Não se aplica (serviço)
# 59               675,00                     Não se aplica (serviço)
#
#                         CONDICAO_PAGAMENTO  \
# 0   Carta de Crédito irrevogável (à vista)
# 1                   Não se aplica (Doação)
# 2                    Net 30 dias (a prazo)
# 3                    Net 30 dias (a prazo)
# 4                    Net 30 dias (a prazo)
# 5                    Net 30 dias (a prazo)
# 6                         Remessa Bancária
# 7                   Não se aplica (Doação)
# 8                    Net 30 dias (a prazo)
# 9                         Remessa Bancária
# 10                  Não se aplica (Doação)
# 11                   Net 30 dias (a prazo)
# 12                           CAD (à vista)
# 13                  Não se aplica (Doação)
# 14                           CAD (à vista)
# 15                   Net 30 dias (a prazo)
# 16                  Não se aplica (Doação)
# 17                   Net 30 dias (a prazo)
# 18                           CAD (à vista)
# 19                           CAD (à vista)
# 20                           CAD (à vista)
# 21                           CAD (à vista)
# 22                  Não se aplica (Doação)
# 23                   Net 30 dias (a prazo)
# 24                        Remessa Bancária
# 25                        Remessa Bancária
# 26                   Net 30 dias (a prazo)
# 27                        Remessa Bancária
# 28                  Não se aplica (Doação)
# 29                                     NaN
# 30                                     NaN
# 31  Carta de Crédito irrevogável (à vista)
# 32                       Cartão de Crédito
# 33  Carta de Crédito irrevogável (à vista)
# 34                   Net 30 dias (a prazo)
# 35                  Não se aplica (Doação)
# 36                   Net 30 dias (a prazo)
# 37                           CAD (à vista)
# 38                  Não se aplica (Doação)
# 39                  Não se aplica (Doação)
# 40                  Não se aplica (Doação)
# 41                   Net 30 dias (a prazo)
# 42  Carta de Crédito irrevogável (à vista)
# 43                   Net 30 dias (a prazo)
# 44                                     NaN
# 45  Carta de Crédito irrevogável (à vista)
# 46                   Net 30 dias (a prazo)
# 47                           CAD (à vista)
# 48                           CAD (à vista)
# 49                           CAD (à vista)
# 50                   Net 30 dias (a prazo)
# 51              Remessa Financeira à Vista
# 52                              Antecipado
# 53                           CAD (à vista)
# 54              Remessa Financeira à Vista
# 55                           CAD (à vista)
# 56              Remessa Financeira à Vista
# 57              Remessa Financeira à Vista
# 58              Remessa Financeira à Vista
# 59              Remessa Financeira à Vista
#
#                                          NOTA_EMPENHO  \
# 0   2019NE800185\n2019NE800186\n2020NE800054\n2020...
# 1                                        2019NE800044
# 2                                        2019NE800108
# 3                                        2019NE800145
# 4                                        2019NE800184
# 5                                        2019NE800233
# 6                                        2019NE800252
# 7                                        2019NE800201
# 8                                        2019NE800292
# 9                                        2019NE800553
# 10                                       2019NE800305
# 11                                       2019NE800482
# 12                         2019NE800494\n2020NE800207
# 13                                       2019NE800671
# 14                                       2019NE800784
# 15                         2020NE800116\n2020NE800150
# 16                                      2020NE800108
# 17                                       2020NE800208
# 18                                       2020NE800301
# 19                                       2020NE800206
# 20                                       2020NE800180
# 21                                       2020NE800183
# 22                                       2020NE800128
# 23                                       2020NE800197
# 24                                       2020NE800557
# 25                                       2020NE800513
# 26                                       2020NE800266
# 27                                       2020NE800379
# 28                                       2020NE800393
# 29                                                NaN
# 30                                                NaN
# 31                                       2020NE800504
# 32                                       2020NE800526
# 33                                       2021NE000110
# 34                                       2021NE000123
# 35                                       2021NE000038
# 36                                       2021NE000107
# 37                                       2021NE000153
# 38                                       2021NE000078
# 39                                       2021NE000104
# 40                                       2021NE000105
# 41                                       2021NE000250
# 42                         2021NE000272\n2021NE000273
# 43                                       2021NE000261
# 44                                                NaN
# 45                                       2021NE000245
# 46                                       2020NE800536
# 47                                       2021NE000313
# 48                                       2021NE000289
# 49                                       2021NE000314
# 50                         2021NE000294\n2021NE000295
# 51                                       2021NE000213
# 52                               Será emitida em 2022
# 53                               Será emitida em 2022
# 54                               Será emitida em 2022
# 55                                       2021NE000311
# 56                                       2021NE000306
# 57                                       2021NE000248
# 58                               Será emitida em 2022
# 59                                       2021NE000287
#
#       DECLARACAO_IMPORTACAO                DESP_CAMBIO_BANCO DESP_FORNECEDOR  \
# 0              20/0824764-2                 R$ 3.089.146,54    R$ 25.088,19
# 1              19/0456067-0                          R$ -         R$ 492,78
# 2              19/0898065-8                    R$ 21.223,08     R$ 2.489,17
# 3              19/1124450-9                     R$ 2.855,27     R$ 3.420,91
# 4              19/1315265-2                    R$ 42.062,34     R$ 3.362,32
# 5              19/1382172-4                     R$ 4.427,78     R$ 2.930,87
# 6              19/1462936-3                     R$ 4.993,94     R$ 2.871,84
# 7              19/1533994-6                          R$ -       R$ 4.503,52
# 8              19/1854476-1                     R$ 8.891,13     R$ 2.985,27
# 9   Não se aplica (serviço)                     R$ 3.900,40          R$ -
# 10             19/1626632-2                          R$ -       R$ 1.480,82
# 11             19/2300196-7                     R$ 9.327,54     R$ 3.336,82
# 12             20/1488802-6                     R$ 5.622,82     R$ 1.917,64
# 13             19/2341317-3                               -     R$ 4.342,31
# 14             20/0137605-6                    R$ 13.828,33     R$ 4.144,62
# 15             20/1021494-2                    R$ 10.559,80     R$ 4.584,92
# 16             20/1008460-7                               -    R$ 10.374,19
# 17            20/1986488-5                     R$ 35.943,49     R$ 5.993,06
# 18             20/2047366-5                    R$ 71.266,25     R$ 7.164,13
# 19             20/1553898-3                   R$ 117.175,38     R$ 7.806,81
# 20             20/1175402-9                     R$ 9.024,93     R$ 5.424,08
# 21             20/1177583-2                    R$ 29.601,79     R$ 5.525,28
# 22             20/1053043-7                               -     R$ 7.729,22
# 23            20/1514064-5                    R$ 229.113,19     R$ 6.225,70
# 24  Não se aplica (serviço)                    R$ 36.163,75               -
# 25  Não se aplica (serviço)                   R$ 315.056,47               -
# 26             20/1518797-8                    R$ 17.833,04     R$ 4.700,03
# 27  Não se aplica (serviço)                     R$ 4.782,81               -
# 28             21/0089708-9                               -     R$ 1.521,62
# 29                      NaN                              NaN             NaN
# 30                      NaN                              NaN             NaN
# 31             21/0752353-2                   R$ 392.371,27     R$ 9.140,54
# 32  Não se aplica (serviço)                     R$ 4.750,84               -
# 33             21/2184603-3                    R$ 14.245,00     R$ 5.741,52
# 34             21/2057745-4                     R$ 5.050,66     R$ 6.708,94
# 35             21/0944724-8                               -     R$ 5.805,35
# 36             21/2043157-3                    R$ 54.659,92     R$ 5.946,79
# 37             21/1966130-7                    R$ 35.913,06     R$ 5.696,72
# 38             21/1448366-4                               -     R$ 2.253,67
# 39             21/1424996-3                               -     R$ 8.008,68
# 40             21/1562752-0                               -    R$ 10.384,30
# 41             22/0013019-7   Valores ainda em consolidação              NaN
# 42      Aguardando Embarque                              NaN             NaN
# 43      Aguardando Embarque                              NaN             NaN
# 44                      NaN                              NaN             NaN
# 45      Aguardando Embarque                              NaN             NaN
# 46  Não se aplica (serviço)                   R$ 471.920,87               -
# 47      Aguardando Embarque                              NaN             NaN
# 48      Aguardando Embarque                              NaN             NaN
# 49      Aguardando Embarque                              NaN             NaN
# 50      Aguardando Embarque                              NaN             NaN
# 51  Não se aplica (serviço)                    R$ 48.065,00               -
# 52      Aguardando Embarque                              NaN             NaN
# 53      Aguardando Embarque                              NaN             NaN
# 54  Não se aplica (serviço)           Aguardando pagamentos              NaN
# 55      Aguardando Embarque                              NaN             NaN
# 56  Não se aplica (serviço)                     R$ 5.286,37               -
# 57  Não se aplica (serviço)                     R$ 1.904,29               -
# 58  Não se aplica (serviço)           Aguardando pagamentos              NaN
# 59  Não se aplica (serviço)                     R$ 4.423,83               -
#
#    DESP_ORGAO_ANUENTE
# 0      R$ 190.382,81
# 1        R$ 4.658,26
# 2          R$ 677,55
# 3          R$ 508,68
# 4          R$ 696,51
# 5          R$ 265,15
# 6          R$ 505,44
# 7        R$ 1.577,87
# 8          R$ 621,52
# 9             R$ -
# 10       R$ 2.165,78
# 11         R$ 462,13
# 12         R$ 325,54
# 13         R$ 235,53
# 14       R$ 1.165,74
# 15          R$ 82,59
# 16         R$ 134,96
# 17         R$ 686,09
# 18       R$ 1.696,12
# 19       R$ 2.758,89
# 20         R$ 196,69
# 21         R$ 566,71
# 22          R$ 25,09
# 23       R$ 4.094,32
# 24                 -
# 25                 -
# 26          R$ 59,62
# 27                 -
# 28         R$ 443,27
# 29                NaN
# 30                NaN
# 31       R$ 8.395,34
# 32                 -
# 33         R$ 781,51
# 34         R$ 161,07
# 35          R$ 15,17
# 36         R$ 419,04
# 37         R$ 680,46
# 38         R$ 528,68
# 39         R$ 212,19
# 40         R$ 683,84
# 41                NaN
# 42                NaN
# 43                NaN
# 44                NaN
# 45                NaN
# 46                 -
# 47                NaN
# 48                NaN
# 49                NaN
# 50                NaN
# 51                 -
# 52                NaN
# 53                NaN
# 54                NaN
# 55                NaN
# 56                 -
# 57                 -
# 58                NaN
# 59                 -

# %% [markdown]
# <br>
#
# * TRATAMENTO: ANÁLISE EXPLORATÓRIA E TRANSFORMAÇÃO DOS DADOS

# %% [markdown]
# <br>
# ANÁLISE EXPLORATÓRIA:

# %%
#CRIANDO UM BACKUP DO DATAFRAME:

backup = df.copy()

# %%
# VERIFICANDO A CONSISTÊNCIA DOS TIPOS DE DADOS

df.dtypes

# %%
# VERIFICANDO DADOS NULOS

df.isna().sum()

# %%
# VERIFICANDO QUANTOS E QUAIS TIPOS DE MOEDAS DIFERENTES EXISTEM NO DATAFRAME

df.MOEDA.value_counts()

# %%
# VERIFICANDO A EXISTÊNCIA DE PRODUTOS REPETIDOS OU INCONSISTENTES

df.PRODUTO_OU_SERVICO.value_counts()

# %%
# VERIFICANDO A EXISTENCIA DE CANCELAMENTOS NAS DISPENSAS

pd.unique(df['NUM_DISPENSA'])

# %%
# VERIFICANDO A EXISTÊNCIA DE VALORES NULOS NAO IDENTIFICADOS COMO "NaN'

df.DESP_FORNECEDOR.value_counts()

# %%
# VERIFICANDO A EXISTÊNCIA DE VALORES NULOS NAO IDENTIFICADOS COMO "NaN'

df.DESP_CAMBIO_BANCO.value_counts()

# %%
# VERIFICANDO A EXISTÊNCIA DE VALORES NULOS NAO IDENTIFICADOS COMO "NaN'

df.DESP_ORGAO_ANUENTE.value_counts()

# %% [markdown]
# <br>
#
# TRANSFORMAÇÃO DOS DADOS:

# %%
# DROPANDO COLUNAS IRRELEVANTES 

cols = ['LICENCA_IMPORTACAO', 'INCOTERM', 'NOTA_EMPENHO', 'DECLARACAO_IMPORTACAO']
df.drop(cols, axis=1, inplace=True)

# %%
# DROPANDO LINHAS ONDE OS PEDIDOS FORAM CANCELADOS (SEM COBRANCA)

# Encontrando as linhas onde os pedidos foram cancelados
cancelamento = 'Processo cancelado a pedido da área solicitante.' 
cancelamento2 = 'Processo cancelado devido à mudança no escopo de fornecimento (deixou de ser uma doação do órgão de fomento para ser uma compra efetuada pela UFABC, com reembolso posterior pelo órgão de fomento).'

filtro = df.NUM_DISPENSA == cancelamento 
filtro2 = df.NUM_DISPENSA == cancelamento2
df.loc[filtro|filtro2]
# Out:
#             NUM_PROCESSO                                PRODUTO_OU_SERVICO  \
# 29  23006.002378/2020-45        Microscópio Biológico Invertido Trinocular
# 30  23006.002377/2020-09  Sistema de PCR em Tempo Real e Espectrofotômetro
# 44  23006.015796/2021-83                             Rastreadores Oculares
#
#                        EXPORTADOR  \
# 29         Nikon Instruments Inc.
# 30  Life Technologies Corporation
# 44       Gazepoint Research, Inc.
#
#                                          NUM_DISPENSA PAIS_EMBARQUE MOEDA  \
# 29  Processo cancelado devido à mudança no escopo ...           NaN   NaN
# 30  Processo cancelado devido à mudança no escopo ...           NaN   NaN
# 44   Processo cancelado a pedido da área solicitante.           NaN   NaN
#
#    VALOR_MOEDA_EXTERIOR CONDICAO_PAGAMENTO DESP_CAMBIO_BANCO DESP_FORNECEDOR  \
# 29                  NaN                NaN               NaN             NaN
# 30                  NaN                NaN               NaN             NaN
# 44                  NaN                NaN               NaN             NaN
#
#    DESP_ORGAO_ANUENTE
# 29                NaN
# 30                NaN
# 44                NaN

# %%
# Dropando linhas encontrandas pelo seu índice
linhas = [29, 30, 44]
df.drop(linhas, axis=0, inplace=True)

# %%
# CONVERTENDO COLUNAS QUE SERAO UTILIZADAS EM OPERACOES

# Eliminando caracteres das colunas numericas 
# Transformando informações não declaradas em dados nulos 
# Convertendo para o tipo numerico "float"

formatacao = (df['VALOR_MOEDA_EXTERIOR'].str.replace('.', '')
                                        .str.replace(',','.')
                                        .str.replace(' ','')
             )
df['VALOR_MOEDA_EXTERIOR'] = pd.to_numeric(formatacao)


formatacao = (df['DESP_CAMBIO_BANCO'].str.replace('.', '')
                                     .str.replace(',','.')
                                     .str.replace('R','')
                                     .str.replace('$','')
                                     .str.replace('Valores ainda em consolidação','-')
                                     .str.replace('Aguardando pagamentos','-')
                                     .replace('-', np.nan, regex=True)
                                     .str.replace(' ','')
             )
df['DESP_CAMBIO_BANCO'] = pd.to_numeric(formatacao)


formatacao = (df['DESP_FORNECEDOR'].str.replace('.', '')
                                           .str.replace(',','.')
                                           .str.replace(' ','')
                                           .str.replace('R','')
                                           .str.replace('$','')
                                           .replace('-', np.nan, regex=True)
             )
df['DESP_FORNECEDOR'] = pd.to_numeric(formatacao)


formatacao = (df['DESP_ORGAO_ANUENTE'].str.replace('.', '')
                                           .str.replace(',','.')
                                           .str.replace(' ','')
                                           .str.replace('R','')
                                           .str.replace('$','')
                                           .replace('-', np.nan, regex=True)
             )
df['DESP_ORGAO_ANUENTE'] = pd.to_numeric(formatacao)

# %%
# SUBISTIUINDO SIGLAS PELO NOME DA RESPECTIVA MOEDA

sigla = ['USD', 'EUR', 'GBP']
moeda = ['Dolar', 'Euro', 'Libra']

df.loc[df['MOEDA'] == sigla[0], 'MOEDA'] = (moeda[0])
df.loc[df['MOEDA'] == sigla[1], 'MOEDA'] = (moeda[1])
df.loc[df['MOEDA'] == sigla[2], 'MOEDA'] = (moeda[2])

# %%
# ADCIONANDO COLUNA COM VALOR DA COTACAO DA MOEDA ATUALIZADO

df['COTACAO'] = df['MOEDA']
df.loc[df['MOEDA'] == moeda[0], 'COTACAO'] = pd.to_numeric(cot_dolar)
df.loc[df['MOEDA'] == moeda[1], 'COTACAO'] = pd.to_numeric(cot_euro)
df.loc[df['MOEDA'] == moeda[2], 'COTACAO'] = pd.to_numeric(cot_libra)
df['COTACAO'] = pd.to_numeric(df['COTACAO'])

# %%
# ADCIONANDO COLUNA COM VALOR DO CAMBIO DE BANCO ATUALIZADO (COTACAO ATUAL DA RESPECTIVA MOEDA)

df['DESP_CAMBIO_BANCO_ATUAL'] = df['VALOR_MOEDA_EXTERIOR'] * df['COTACAO']

# Não há cobranca quando os produtos ou servicos sao doados, portanto os valores serao zerados
df.loc[df['CONDICAO_PAGAMENTO'] == 'Não se aplica (Doação)', 'DESP_CAMBIO_BANCO_ATUAL'] = np.nan

# %%
# ADCIONANDO COLUNA COM O AUMENTO ENTRE AS DESPESAS DO CAMBIO DE BANCO ATERIORES E ATUAIS

df['AUMENTO_CAMBIO_BANCO'] = df['DESP_CAMBIO_BANCO_ATUAL'] - df['DESP_CAMBIO_BANCO']

# %%
# ADCIONANDO COLUNA COM AS DESPESAS TOTAIS NA EPOCA DA COMPRA

# Criando copias das colunas envolvidas na operacao para realizar alteracoes
desp_cambio = df['DESP_CAMBIO_BANCO']
desp_forn = df['DESP_FORNECEDOR']
desp_org = df['DESP_ORGAO_ANUENTE']

# Tranformando os valores nulos em zero, para realizar operacoes sem perda de valores
nulo = np.nan
desp_cambio = desp_cambio.replace(nulo, 0)
desp_forn = desp_forn.replace(nulo, 0)
desp_org = desp_org.replace(nulo, 0)

# Criando nova coluna com a soma das despesas totais
df['DESP_TOTAL'] = desp_cambio + desp_forn + desp_org

# %%
# ADCIONANDO COLUNA COM O QUE SERIAM AS DESPESAS TOTAIS ATUALMENTE

# Criando copias das colunas envolvidas na operacao para realizar alteracoes
desp_cambio = df['DESP_CAMBIO_BANCO_ATUAL']

# Tranformando os valores nulos em zero, para realizar operacoes sem perda de valores
desp_cambio = desp_cambio.replace(nulo, 0)

# Criando nova coluna com a soma das despesas totais
df['DESP_TOTAL_ATUAL'] = desp_cambio + desp_forn + desp_org

# %% [markdown]
# <br>
#
# * CARREGAMENTO: EXPORTAÇÃO DA BASE DE DADOS TRATADA

# %%
# ARREDONDANDO VALORES PARA FACILITAR A ANALISE

df2 = df.round(2) 
display(df2)

# %%
# IMPORNTAND BASE DE DADOS TRATADA

df2.to_csv('importacao_tratado.csv', index=False)
